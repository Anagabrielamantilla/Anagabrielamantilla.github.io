# %% [markdown]
# # <image src="https://drive.google.com/uc?export=view&id=1uijc4avQRG5ou97pTq_rUWu8i5OCWiHe" width=100%>

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# Conectar el directorio donde está la función

import sys
sys.path.append('/content/drive/MyDrive/CURSO_PYTHON/PLAN/04_Webinar/Publico')

# %%
from class_suelos import clasificacion
from class_suelos import suelos_finos
import pandas as pd

# %%
# Importar datos

df = pd.read_excel('/content/drive/MyDrive/CURSO_PYTHON/PLAN/04_Webinar/Publico/suelos.xlsx')

# %%
df

# %%
help(suelos_finos)

# %%
suelos_finos(25,9,40,50,10)
# Out:
# 'Arcilla fina gravosa CL'

# %% [markdown]
# **Apliquemos la función**

# %%
suelos_finos(df['GRAVA'], df['ARENA'], df['FINOS'], df['IP'], df['LL'])

# %%
suelos_finos(0,30,70, 8, 25)
# Out:
# 'Arcilla fina arenosa CL'

# %% [markdown]
# **Definamos una función de mapeo**

# %%
df
# Out:
#   SUELO  GRAVA  ARENA  FINOS   CU   CC    LL     IP
# 0    S1      0     55     45  3.0  1.0  35.0  21.00
# 1    S2      2     43     55  2.0  5.0  10.0  70.00
# 2    S3      3     37     60  8.0  7.0  48.0   6.00
# 3    S4      0     42     58  7.0  3.0  50.0  55.00
# 4    S5      7     20     73  6.0  2.0  32.6   4.58
# 5    S6      2     39     59  1.0  1.5   8.0  44.00
# 6    S7      1     37     62  1.9  6.0  12.0   2.10
# 7    S8      0     22     78  5.5  6.5  22.0  80.00

# %%
def numbers(grava, arena, finos, IP, LL):
  a = []
  for i in range(len(grava)):
    a.append(suelos_finos(grava[i], arena[i], finos[i], IP[i], LL[i]))
  return a

# %%
df.head(2)
# Out:
#   SUELO  GRAVA  ARENA  FINOS   CU   CC    LL    IP
# 0    S1      0     55     45  3.0  1.0  35.0  21.0
# 1    S2      2     43     55  2.0  5.0  10.0  70.0

# %%
df['clasificación'] = numbers(df['GRAVA'], df['ARENA'], df['FINOS'], df['IP'], df['LL'])

# %%
df
# Out:
#   SUELO  GRAVA  ARENA  FINOS   CU   CC    LL     IP  \
# 0    S1      0     55     45  3.0  1.0  35.0  21.00
# 1    S2      2     43     55  2.0  5.0  10.0  70.00
# 2    S3      3     37     60  8.0  7.0  48.0   6.00
# 3    S4      0     42     58  7.0  3.0  50.0  55.00
# 4    S5      7     20     73  6.0  2.0  32.6   4.58
# 5    S6      2     39     59  1.0  1.5   8.0  44.00
# 6    S7      1     37     62  1.9  6.0  12.0   2.10
# 7    S8      0     22     78  5.5  6.5  22.0  80.00
#
#                      clasificación
# 0          Arcilla fina arenosa CL
# 1          Arcilla fina arenosa CL
# 2     Arcilla arenosa-limosa CL-ML
# 3  Arcilla gruesa o limo elástico
# 4     Arcilla arenosa-limosa CL-ML
# 5          Arcilla fina arenosa CL
# 6                  Limo arenoso ML
# 7          Arcilla fina arenosa CL

# %% [markdown]
# **¿Qué pasaría si no todos los elementos tienen la misma longitud?**

# %%
df['GRAVA']
# Out:
# 0    0
# 1    2
# 2    3
# 3    0
# 4    7
# 5    2
# 6    1
# 7    0
# Name: GRAVA, dtype: int64

# %%
df['GRAVA'][2:]
# Out:
# 2    3
# 3    0
# 4    7
# 5    2
# 6    1
# 7    0
# Name: GRAVA, dtype: int64

# %%
numbers(df['GRAVA'][2:], df['ARENA'], df['FINOS'], df['IP'], df['LL'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-6e041bb0059b> in <module>
# ----> 1 numbers(df['GRAVA'][2:], df['ARENA'], df['FINOS'], df['IP'], df['LL'])
#
# <ipython-input-9-98b166b7fca6> in numbers(grava, arena, finos, IP, LL)
#       2   a = []
#       3   for i in range(len(grava)):
# ----> 4     a.append(suelos_finos(grava[i], arena[i], finos[i], IP[i], LL[i]))
#       5   return a
#
# ...

# %% [markdown]
# **¿Cómo añadir este error en la función?**

# %%
def numbers(grava, arena, finos, IP, LL):
  a = []
  if len(grava)==len(arena)==len(finos)==len(IP)==len(LL):
   for i in range(len(grava)):
       a.append(suelos_finos(grava[i], arena[i], finos[i], IP[i], LL[i]))   
   return a
  else: 
    raise Exception("ERROR: Verifique que todas sus variables sean de la misma longitud")

# %%
df['clasificación'] = numbers(df['GRAVA'][2:], df['ARENA'], df['FINOS'], df['IP'], df['LL'])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-fb4e572cd78f> in <module>
# ----> 1 df['clasificación'] = numbers(df['GRAVA'][2:], df['ARENA'], df['FINOS'], df['IP'], df['LL'])
#
# <ipython-input-16-255d53084d5b> in numbers(grava, arena, finos, IP, LL)
#       6    return a
#       7   else:
# ----> 8     raise Exception("ERROR: Verifique que todas sus variables sean de la misma longitud")
#
# Exception: ERROR: Verifique que todas sus variables sean de la misma longitud

# %% [markdown]
# # **Recursos adicionales**
# ---
#
# En esta sección encontrará material adicional para reforzar los temas y conceptos discutidos:
#
# * [*Python* 3: documentación oficial.](https://docs.python.org/3/)
# * [_Python Básico para Geólogos_: Tutorial de _Python_ (Español)](https://www.youtube.com/watch?v=US1qkMTVjac&list=PLcC-o_GGTQXdyZYJ-YR-f0Toi-fxyVeSI)
# * [_Fundamentos de ingeniería de cimentaciones_](https://issuu.com/gustavochonlongalcivar/docs/fundamentos_de_ingenieria_de_ciment)

# %% [markdown]
# # **Créditos**
# ---
#
# * **Instructores:**
#   * [Ana Gabriela Mantilla, Geóloga](anagmd2019@gmail.com)
#   * [Manuel Daza Restrepo, Geólogo](manedaza12@gmail.com)
#   * [Paul Goyes Peñafiel, PhD (c)](goyes.yesid@gmail.com)
#
#
# **Cursos y Capacitaciones** - *Curso de Programación Científica con Python*
